# %%
import torch

# %%
policy = torch.jit.load("/home/conang/quadruped/unitree_rl_gym/deploy/pre_train/go2/model_1500.pt")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 policy = torch.jit.load("/home/conang/quadruped/unitree_rl_gym/deploy/pre_train/go2/model_1500.pt")
#
# File ~/miniconda3/envs/unitree-rl/lib/python3.8/site-packages/torch/jit/_serialization.py:158, in load(f, map_location, _extra_files, _restore_shapes)
#     156 cu = torch._C.CompilationUnit()
#     157 if isinstance(f, (str, os.PathLike)):
# --> 158     cpp_module = torch._C.import_ir_module(cu, os.fspath(f), map_location, _extra_files, _restore_shapes)  # type: ignore[call-arg]
#     159 else:
#     160     cpp_module = torch._C.import_ir_module_from_buffer(
#     161         cu, f.read(), map_location, _extra_files, _restore_shapes
#     162     )  # type: ignore[call-arg]
#
# RuntimeError: PytorchStreamReader failed locating file constants.pkl: file not found

# %%
model = torch.load("/home/conang/quadruped/unitree_rl_gym/deploy/pre_train/go2/model_1500.pt")

# %%
model
# Out:
# {'model_state_dict': OrderedDict([('std',
#                tensor([0.4886, 0.7988, 0.6604, 0.5108, 0.7436, 0.6977, 0.4730, 0.6337, 0.6421,
#                        0.4714, 0.6132, 0.6446], device='cuda:0')),
#               ('actor.0.weight',
#                tensor([[ 0.0415, -0.1453,  0.0917,  ..., -0.0269,  0.0210, -0.1322],
#                        [-0.0094, -0.1135,  0.1085,  ..., -0.0436, -0.0067,  0.0860],
#                        [ 0.0351,  0.0568,  0.0080,  ...,  0.0345,  0.0600, -0.0250],
#                        ...,
#                        [-0.1051, -0.2534, -0.0615,  ...,  0.0004, -0.0676, -0.0454],
#                        [-0.1793, -0.0210, -0.0619,  ..., -0.0458,  0.1073, -0.0372],
#                        [ 0.0067, -0.1131,  0.2656,  ..., -0.1293,  0.0400, -0.0201]],
#                       device='cuda:0')),
#               ('actor.0.bias',
#                tensor([-1.2350e-01, -2.5592e-01,  4.8214e-02, -5.2453e-02,  1.0534e-01,
# ...

# %%
model['model_state_dict']['actor.0.bias']
# Out:
# OrderedDict([('std',
#               tensor([0.4886, 0.7988, 0.6604, 0.5108, 0.7436, 0.6977, 0.4730, 0.6337, 0.6421,
#                       0.4714, 0.6132, 0.6446], device='cuda:0')),
#              ('actor.0.weight',
#               tensor([[ 0.0415, -0.1453,  0.0917,  ..., -0.0269,  0.0210, -0.1322],
#                       [-0.0094, -0.1135,  0.1085,  ..., -0.0436, -0.0067,  0.0860],
#                       [ 0.0351,  0.0568,  0.0080,  ...,  0.0345,  0.0600, -0.0250],
#                       ...,
#                       [-0.1051, -0.2534, -0.0615,  ...,  0.0004, -0.0676, -0.0454],
#                       [-0.1793, -0.0210, -0.0619,  ..., -0.0458,  0.1073, -0.0372],
#                       [ 0.0067, -0.1131,  0.2656,  ..., -0.1293,  0.0400, -0.0201]],
#                      device='cuda:0')),
#              ('actor.0.bias',
#               tensor([-1.2350e-01, -2.5592e-01,  4.8214e-02, -5.2453e-02,  1.0534e-01,
# ...

# %%
test_model = torch.load("/home/conang/quadruped/unitree_rl_gym/deploy/pre_train/g1/motion.pt")

# %%
test_model
# Out:
# RecursiveScriptModule(
#   original_name=PolicyExporterLSTM
#   (actor): RecursiveScriptModule(
#     original_name=Sequential
#     (0): RecursiveScriptModule(original_name=Linear)
#     (1): RecursiveScriptModule(original_name=ELU)
#     (2): RecursiveScriptModule(original_name=Linear)
#   )
#   (memory): RecursiveScriptModule(original_name=LSTM)
# )

# %%
policy = torch.jit.load("/home/conang/quadruped/unitree_rl_gym/logs/rough_go2/exported/policies/policy_1.pt")

# %%
policy.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 policy.shape
#
# File ~/miniconda3/envs/unitree-rl/lib/python3.8/site-packages/torch/jit/_script.py:823, in RecursiveScriptModule.__getattr__(self, attr)
#     820     self.__dict__[attr] = script_method
#     821     return script_method
# --> 823 return super().__getattr__(attr)
#
# File ~/miniconda3/envs/unitree-rl/lib/python3.8/site-packages/torch/jit/_script.py:530, in ScriptModule.__getattr__(self, attr)
#     528 def __getattr__(self, attr):
#     529     if "_actual_script_module" not in self.__dict__:
# --> 530         return super().__getattr__(attr)
#     531     return getattr(self._actual_script_module, attr)
#
# File ~/miniconda3/envs/unitree-rl/lib/python3.8/site-packages/torch/nn/modules/module.py:1709, in Module.__getattr__(self, name)
#    1707     if name in modules:
# ...
